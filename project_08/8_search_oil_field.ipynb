# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Загрузка-и-подготовка-данных" data-toc-modified-id="Загрузка-и-подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Загрузка и подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Установка-и-импорт-библиотек" data-toc-modified-id="Установка-и-импорт-библиотек-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Установка и импорт библиотек</a></span></li><li><span><a href="#Константы" data-toc-modified-id="Константы-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Константы</a></span></li><li><span><a href="#Функции" data-toc-modified-id="Функции-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Функции</a></span></li><li><span><a href="#Загрузка-данных" data-toc-modified-id="Загрузка-данных-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Загрузка данных</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Предобработка данных</a></span></li><li><span><a href="#Исследовательский-анализ" data-toc-modified-id="Исследовательский-анализ-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Исследовательский анализ</a></span></li><li><span><a href="#Корреляционный-анализ" data-toc-modified-id="Корреляционный-анализ-1.7"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>Корреляционный анализ</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-1.8"><span class="toc-item-num">1.8&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Обучение-и-проверка-модели" data-toc-modified-id="Обучение-и-проверка-модели-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Обучение и проверка модели</a></span><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Подготовка данных</a></span></li><li><span><a href="#Создание-пайплайна" data-toc-modified-id="Создание-пайплайна-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Создание пайплайна</a></span></li><li><span><a href="#Обучение-и-выбор-лучшей-модели" data-toc-modified-id="Обучение-и-выбор-лучшей-модели-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Обучение и выбор лучшей модели</a></span><ul class="toc-item"><li><span><a href="#Выбор-метрики" data-toc-modified-id="Выбор-метрики-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>Выбор метрики</a></span></li><li><span><a href="#Модель-для-geo_data_0" data-toc-modified-id="Модель-для-geo_data_0-2.3.2"><span class="toc-item-num">2.3.2&nbsp;&nbsp;</span>Модель для geo_data_0</a></span></li><li><span><a href="#Модель-для-geo_data_1" data-toc-modified-id="Модель-для-geo_data_1-2.3.3"><span class="toc-item-num">2.3.3&nbsp;&nbsp;</span>Модель для geo_data_1</a></span></li><li><span><a href="#Модель-для-geo_base_2" data-toc-modified-id="Модель-для-geo_base_2-2.3.4"><span class="toc-item-num">2.3.4&nbsp;&nbsp;</span>Модель для geo_base_2</a></span></li><li><span><a href="#Dummy-модели" data-toc-modified-id="Dummy-модели-2.3.5"><span class="toc-item-num">2.3.5&nbsp;&nbsp;</span>Dummy-модели</a></span></li></ul></li><li><span><a href="#Предсказания-на-валидационной-выборке" data-toc-modified-id="Предсказания-на-валидационной-выборке-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Предсказания на валидационной выборке</a></span><ul class="toc-item"><li><span><a href="#Модель-geo_base_0" data-toc-modified-id="Модель-geo_base_0-2.4.1"><span class="toc-item-num">2.4.1&nbsp;&nbsp;</span>Модель geo_base_0</a></span></li><li><span><a href="#Модель-geo_base_1" data-toc-modified-id="Модель-geo_base_1-2.4.2"><span class="toc-item-num">2.4.2&nbsp;&nbsp;</span>Модель geo_base_1</a></span></li><li><span><a href="#Модель-geo_base_2" data-toc-modified-id="Модель-geo_base_2-2.4.3"><span class="toc-item-num">2.4.3&nbsp;&nbsp;</span>Модель geo_base_2</a></span></li></ul></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Подготовка-к-расчёту-прибыли" data-toc-modified-id="Подготовка-к-расчёту-прибыли-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Подготовка к расчёту прибыли</a></span></li><li><span><a href="#Расчёт-прибыли-и-рисков" data-toc-modified-id="Расчёт-прибыли-и-рисков-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Расчёт прибыли и рисков</a></span><ul class="toc-item"><li><span><a href="#Выводы" data-toc-modified-id="Выводы-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Выбор локации для скважины

# %% [markdown]
# Допустим, вы работаете в добывающей компании «ГлавРосГосНефть». Нужно решить, где бурить новую скважину.
#
# Вам предоставлены пробы нефти в трёх регионах: в каждом 10 000 месторождений, где измерили качество нефти и объём её запасов. Постройте модель машинного обучения, которая поможет определить регион, где добыча принесёт наибольшую прибыль. Проанализируйте возможную прибыль и риски техникой *Bootstrap.*
#
# Шаги для выбора локации:
#
# - В избранном регионе ищут месторождения, для каждого определяют значения признаков;
# - Строят модель и оценивают объём запасов;
# - Выбирают месторождения с самым высокими оценками значений. Количество месторождений зависит от бюджета компании и стоимости разработки одной скважины;
# - Прибыль равна суммарной прибыли отобранных месторождений.
#
# **Описание данных**
#
# Данные геологоразведки трёх регионов находятся в файлах:
#
# - `/datasets/geo_data_0.csv`. [Скачать датасет](https://code.s3.yandex.net/datasets/geo_data_0.csv)
# - `/datasets/geo_data_1.csv`. [Скачать датасет](https://code.s3.yandex.net/datasets/geo_data_1.csv)
# - `/datasets/geo_data_2.csv`. [Скачать датасет](https://code.s3.yandex.net/datasets/geo_data_2.csv)
#
#
# - *id* — уникальный идентификатор скважины;
# - *f0, f1, f2* — три признака точек (неважно, что они означают, но сами признаки значимы);
# - *product* — объём запасов в скважине (тыс. баррелей).
#
# **План по выполнению проекта**
#
# 1. Загрузите и подготовьте данные. Поясните порядок действий.
# 2. Обучите и проверьте модель для каждого региона:
#
#     2.1. Разбейте данные на обучающую и валидационную выборки в соотношении 75:25.
#
#     2.2. Обучите модель и сделайте предсказания на валидационной выборке.
#
#     2.3. Сохраните предсказания и правильные ответы на валидационной выборке.
#
#     2.4. Напечатайте на экране средний запас предсказанного сырья и *RMSE* модели.
#
#     2.5. Проанализируйте результаты.
#
# 3. Подготовьтесь к расчёту прибыли:
#
#     3.1. Все ключевые значения для расчётов сохраните в отдельных переменных.
#
#     3.2. Рассчитайте достаточный объём сырья для безубыточной разработки новой скважины. Сравните полученный объём сырья со средним запасом в каждом регионе.
#
#     3.3. Напишите выводы по этапу подготовки расчёта прибыли.
#
# 4. Напишите функцию для расчёта прибыли по выбранным скважинам и предсказаниям модели:
#
#     4.1. Выберите скважины с максимальными значениями предсказаний.
#
#     4.2. Просуммируйте целевое значение объёма сырья, соответствующее этим предсказаниям.
#
#     4.3. Рассчитайте прибыль для полученного объёма сырья.
#
# 5. Посчитайте риски и прибыль для каждого региона:
#
#     5.1. Примените технику *Bootstrap* с 1000 выборок, чтобы найти распределение прибыли.
#
#     5.2. Найдите среднюю прибыль, 95%-й доверительный интервал и риск убытков. Убыток — это отрицательная прибыль.
#
#     5.3. Напишите выводы: предложите регион для разработки скважин и обоснуйте выбор.

# %% [markdown]
# ## Загрузка и подготовка данных

# %% [markdown]
# ### Установка и импорт библиотек

# %%
# !pip install phik -q
# !pip install imblearn -q

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import time

from phik import phik_matrix

from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score

from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import (
    StandardScaler,
    MinMaxScaler,
    RobustScaler,
    PolynomialFeatures
)
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error, root_mean_squared_error, make_scorer

from imblearn.pipeline import Pipeline as ImbPipeline

from sklearn.dummy import DummyRegressor

from scipy import stats as st

# %% [markdown]
# ### Константы

# %%
RANDOM_STATE = 42
STATE = np.random.RandomState(12345)

# %% [markdown]
# ### Функции

# %%
def load_csv(file_path, file_url=None):
    """
    Загружает данные из локального CSV файла или по URL.

    Функция проверяет, существует ли файл по указанному пути. 
    Если файл существует, данные загружаются из него. 
    В противном случае данные загружаются по указанному URL, если он предоставлен.
    
    Параметры:
    file_path (str): Путь к локальному файлу CSV.
    file_url (str, optional): URL для загрузки данных, если файл не найден.

    Возвращает:
    DataFrame или None: Загруженные данные в формате DataFrame, или None в случае ошибки.
    """
    try:
        # Проверяем, существует ли файл по указанному пути
        if os.path.exists(file_path):
            return pd.read_csv(file_path)
        elif file_url:
            # Загружаем данные из URL, если файл не найден
            return pd.read_csv(file_url)
        else:
            print("File not found and no URL provided.")
            return None
    except Exception as e:
        # В случае ошибки выводим сообщение
        print("Something went wrong")
        return None

# %%
# Создаем функцию для вывода общей информации о датасете
def df_info(data):
    """
    Эта функция выводит общую информацию о переданном датасете, включая:
    1. Первые 5 строк для предварительного просмотра.
    2. Общую информацию о типах данных и количестве ненулевых значений.
    3. Статистику по колонкам, включая описательные статистики.
    4. Долю пропусков в каждом столбце.
    5. Количество полных дубликатов в датасете.
    
    Параметры:
    data : pd.DataFrame
        Датасет, для которого нужно вывести информацию.
    """
    
    # 1. Выводим первые 5 строк датасета для предварительного просмотра
    print(f'1. Первые 5 строк датасета:')
    display(data.head())
          
    # 2. Выводим общую информацию о датасете
    print('\n2. Общая информация о датасете:')
    print(data.info())
    
    # 3. Выводим статистику по колонкам
    print('\n3. Статистика по колонкам:')
    display(data.describe(include='all'))
    
    # 4. Вычисляем и отображаем долю пропусков в колонках
    print('\n4. Доля пропусков в колонках:')
    missing_data = pd.DataFrame(round(data.isna().mean() * 100, 4).sort_values())
    display(missing_data.style.background_gradient('coolwarm'))
    
    # 5. Подсчитываем и выводим количество полных дубликатов
    print('\n5. Количество полных дубликатов:', data.duplicated().sum())

# %%
def plot_box_hist_chart(data, plot_type='both', x_label='Значение признака', y_label='Частота', title=None, hue=None, palette=None, bins='auto'):
    """
    Функция для отображения диаграмм размаха и гистограмм для числовых столбцов в DataFrame.

    Параметры:
    - data: DataFrame или Series, данные для визуализации
    - plot_type: str, определяет тип графиков: 'boxplot', 'histplot' или 'both' (по умолчанию 'both')
    - x_label: str, подпись оси X (по умолчанию 'Значение признака')
    - y_label: str, подпись оси Y (по умолчанию 'Частота')
    - title: str, заголовок графика (по умолчанию None)
    - hue: str, имя столбца для цветового кодирования гистограммы (по умолчанию None)
    - palette: str, цветовая палитра для графиков (по умолчанию None)
    - bins: int, количество столбцов в гистограмме (по умолчанию 'auto')

    Возвращает:
    - Выводит диаграммы размаха и гистограмм на основе переданных данных.
    """

    # Проверка, являются ли данные объектом Series, и приведение к DataFrame при необходимости
    if isinstance(data, pd.Series):
        data = pd.DataFrame(data)

    # Выбор числовых столбцов из данных
    numerical_cols = data.select_dtypes(include=['number']).columns
    num_plots = len(numerical_cols)

    # Создание подходящего количества подграфиков в зависимости от числа числовых столбцов
    if num_plots == 1:
        fig, axes = plt.subplots(1, 2, figsize=(12, 3))
        axes = [axes]
    else:
        fig, axes = plt.subplots(num_plots, 2, figsize=(12, 3 * num_plots))

    # Построение графиков для каждого числового столбца
    for i, col in enumerate(numerical_cols):
        # Диаграмма размаха
        if plot_type == 'boxplot' or plot_type == 'both':
            sns.boxplot(x=data[col], ax=axes[i][0], palette=palette)
            axes[i][0].set_xlabel(x_label)
            axes[i][0].set_title(f'Диаграмма размаха по колонке: {col}')

        # Гистограмма
        if plot_type == 'histplot' or plot_type == 'both':
            if hue is not None:
                sns.histplot(x=data[col], bins=bins, palette=palette, kde=True, ax=axes[i][1], hue=data[hue])
            else:
                sns.histplot(x=data[col], bins=bins, palette=palette, kde=True, ax=axes[i][1])
            axes[i][1].set_xlabel(x_label)
            axes[i][1].set_ylabel(y_label)
            axes[i][1].set_title(f'Распределение значений в колонке: {col}')

            # Добавление линий для mean, median и mode
            mean_val = data[col].mean()
            median_val = data[col].median()
            mode_val = data[col].mode()[0]  # Берем первую моду

            axes[i][1].axvline(mean_val, color='red', linestyle='--', label='Среднее')
            axes[i][1].axvline(median_val, color='blue', linestyle='--', label='Медиана')
            axes[i][1].axvline(mode_val, color='green', linestyle='--', label='Мода')

            # Добавление легенды при наличии hue
            if hue is not None:
                axes[i][1].legend(title=hue)

    # Улучшение компоновки графиков и вывод
    plt.tight_layout()
    plt.show()

# %%
def find_best_model_grid(pipe, param_grid, X_train, y_train, scoring, cv=5, n_jobs=-1):
    """
    Поиск лучшей модели с использованием GridSearch для оптимизации гиперпараметров.
    
    Параметры:
    pipe : sklearn.pipeline.Pipeline
        Пайплайн модели для обучения.
    param_grid : dict
        Словарь с гиперпараметрами для поиска.
    n_jobs : int, optional
        Количество потоков для параллельного выполнения (-1 для использования всех доступных).
    
    Возвращает:
        Объект GridSearch с обученной моделью и DataFrame с результатами.
    """
    
    # 1. Инициализация GridSearchCV
    grid_search = GridSearchCV(
        pipe,
        param_grid,
        cv=cv,  # 5-кратная перекрестная проверка по умолчанию
        scoring=scoring, 
        n_jobs=n_jobs  # Параллельное выполнение
    )

    # 2. Обучение модели на тренировочных данных
    grid_search.fit(X_train, y_train)

    # 3. Вывод информации о лучшей модели и её параметрах
    print('Лучшая модель и её параметры')
    
    if cv is not None:
        print('Лучшая метрика на кросс-валидации для лучшей модели:', abs(grid_search.best_score_))  # Лучшая метрика на обучении  
    else: 
        print('Лучшая метрика для лучшей модели:', abs(grid_search.best_score_))  # Лучшая метрика на обучении     
    
    display(grid_search.best_estimator_)  # Отображение лучшего оценивателя
              
    # 4. Сохранение результатов в DataFrame
    results = pd.DataFrame(grid_search.cv_results_)  # Сохранение результатов в таблицу
  
    
    # 5. Возврат объекта GridSearch и DataFrame с результатами
    return grid_search, results

# %%
def print_metrics(model, X_test, y_test):
    # Получаем предсказания модели
    y_test_pred = model.predict(X_test)
    
    # Вычисляем метрики
    r2 = r2_score(y_test, y_test_pred)
    mse = mean_squared_error(y_test, y_test_pred)
    rmse = root_mean_squared_error(y_test, y_test_pred)
    mae = mean_absolute_error(y_test, y_test_pred)

    # Вывод оценок
    print("R2 LinearRegression =", round(r2, 4))
    print(f'MSE = {mse:.4f}')
    print(f'RMSE = {rmse:.4f}')
    print(f'MAE = {mae:.4f}')
    print()

# %%
def analyze_model_predictions(best_model, X_train, X_valid, y_valid):
    """
    Анализирует предсказания, сделанные лучшей моделью на валидационном наборе данных.

    Параметры:
    - best_model: Обученная модель, включающая предобработку и оценщик модели.
    - X_train: Признаки обучающего набора данных, использованные для тренировки модели.
    - X_valid: Признаки валидационного набора данных, для которых будут сделаны предсказания.
    - y_valid: Истинные значения для валидационного набора данных.

    Возвращает:
    - y_valid_pred: Предсказанные значения для валидационного набора данных.
    """

    # Получаем предсказания для валидационного набора
    y_valid_pred = best_model.predict(X_valid)

    # Извлекаем модель после обработки
    model = best_model.best_estimator_.named_steps['models']
    
    # Применяем предобработку к тренировочным данным
    X_train_processed = pd.DataFrame(
        best_model.best_estimator_.named_steps['preprocessor'].transform(X_train),
        columns=best_model.best_estimator_.named_steps['preprocessor'].get_feature_names_out()
    )
    
    # Отображаем первые несколько строк обработанных данных
    print('Первые 5 строк тренировочного датасета (после обработки):')
    display(X_train_processed.head())

    # Извлекаем коэффициенты модели для анализа важности признаков
    coefficients = model.coef_
    feature_importances = pd.DataFrame({
        'Feature': X_train_processed.columns,  # Названия признаков
        'Importance': coefficients  # Коэффициенты модели
    }).sort_values(by='Importance', key=abs, ascending=False)  # Сортируем по абсолютной важности

    # Визуализируем важности признаков
    plt.figure(figsize=(10, 4))
    plt.barh(feature_importances['Feature'], feature_importances['Importance'], color='green')
    plt.xlabel('Важность')  # Подпись для оси X
    plt.ylabel('Признаки')  # Подпись для оси Y
    plt.title('Важности признаков')  # Заголовок графика
    plt.gca().invert_yaxis()  # Переворачиваем ось Y для лучшей читаемости
    plt.show()

    # Вычисляем метрики качества модели
    r2 = r2_score(y_valid, y_valid_pred)  # Коэффициент детерминации
    mse = mean_squared_error(y_valid, y_valid_pred)  # Среднеквадратичная ошибка
    rmse = np.sqrt(mse)  # Корень из среднеквадратичной ошибки
    mae = mean_absolute_error(y_valid, y_valid_pred)  # Средняя абсолютная ошибка

    # Выводим метрики для оценки качества модели
    print("R2 LinearRegression =", round(r2, 4))  # Вывод R^2
    print(f'MSE = {mse:.4f}')  # Вывод MSE
    print(f'RMSE = {rmse:.4f}')  # Вывод RMSE
    print(f'MAE = {mae:.4f}\n')  # Вывод MAE
    print(f'Среднее предсказанное значение = {round(y_valid_pred.mean(), 4)}')  # Среднее предсказанное значение
    print()

    # Возвращаем предсказанные значения для валидационного набора
    return y_valid_pred

# %%
def plot_residuals(y_true, y_pred):
    """
    Функция для визуализации остатков модели.
    
    Параметры:
    y_true : array-like
        Истинные значения целевой переменной.
    y_pred : array-like
        Предсказанные значения целевой переменной моделью.

    Эта функция строит график остатков и гистограмму остатков, 
    позволяя оценить качество модели.
    """
    # Вычисляем остатки (разницу между истинными и предсказанными значениями)
    residuals = y_true - y_pred
    
    # Устанавливаем стиль графиков
    sns.set(style="whitegrid")
    
    # Создаем фигуру для графиков
    plt.figure(figsize=(12, 5))
    
    # Подграфик 1: График остатков
    plt.subplot(1, 2, 1)
    sns.residplot(x=y_pred, y=residuals, lowess=True, line_kws=dict(color="g"))
    
    # Добавляем линии для среднего и медианы остатков
    plt.axhline(y=residuals.mean(), color='r', linestyle='--', label='Среднее остатков')
    plt.axhline(y=residuals.median(), color='r', linestyle='-', label='Медиана остатков')
    
    # Настраиваем заголовок и метки осей
    plt.title('График остатков')
    plt.xlabel('Предсказанные значения')
    plt.ylabel('Остатки')
    plt.legend()  # Показываем легенду
    plt.grid(True)  # Включаем сетку
    
    # Подграфик 2: Гистограмма остатков
    plt.subplot(1, 2, 2)
    sns.histplot(residuals, kde=True, color="b")
    
    # Добавляем линии для среднего и медианы остатков
    plt.axvline(x=residuals.mean(), color='r', linestyle='-', label='Среднее остатков')
    plt.axvline(x=residuals.median(), color='r', linestyle='--', label='Медиана остатков')
    
    # Настраиваем заголовок и метки осей
    plt.title('Гистограмма остатков')
    plt.xlabel('Остатки')
    plt.ylabel('Частота')
    plt.legend()  # Показываем легенду
    plt.grid(True)  # Включаем сетку
    
    # Подгоняем макет графиков
    plt.tight_layout()
    
    # Отображаем графики
    plt.show()

# %% [markdown]
# ### Загрузка данных

# %%
# Определяем пути к файлам
geo_data_0_path = '/datasets/geo_data_0.csv'
geo_data_0_url = 'https://code.s3.yandex.net/datasets/geo_data_0.csv'

geo_data_1_path = '/datasets/geo_data_1.csv'
geo_data_1_url = 'https://code.s3.yandex.net/datasets/geo_data_1.csv'

geo_data_2_path = '/datasets/geo_data_2.csv'
geo_data_2_url = 'https://code.s3.yandex.net/datasets/geo_data_2.csv'

# %%
# Загрузим и сохраним данные в отдельные переменные
geo_data_0 = load_csv(geo_data_0_path, geo_data_0_url)
geo_data_1 = load_csv(geo_data_1_path, geo_data_1_url)
geo_data_2 = load_csv(geo_data_2_path, geo_data_2_url)

# %%
# Посмотрим общую информацию о датафрейме
df_info(geo_data_0)
# Out:
# 1. Первые 5 строк датасета:
#       id        f0        f1        f2     product
# 0  txEyH  0.705745 -0.497823  1.221170  105.280062
# 1  2acmU  1.334711 -0.340164  4.365080   73.037750
# 2  409Wp  1.022732  0.151990  1.419926   85.265647
# 3  iJLyR -0.032172  0.139033  2.978566  168.620776
# 4  Xdl7t  1.988431  0.155413  4.751769  154.036647
# 2. Общая информация о датасете:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 5 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   id       100000 non-null  object
#  1   f0       100000 non-null  float64
#  2   f1       100000 non-null  float64
#  3   f2       100000 non-null  float64
#  4   product  100000 non-null  float64
# dtypes: float64(4), object(1)
# memory usage: 3.8+ MB
# None
#
# 3. Статистика по колонкам:
#             id             f0             f1             f2        product
# ...

# %% [markdown]
# Данные в датафрейме представляют собой набор из 100,000 записей, содержащих 5 колонок:
# - `id`: Содержит 99,990 уникальных значений типа строка (object). Наиболее распространённый идентификатор встречается 2 раза. Вероятно, есть записи с дублирующимися `id`.
# - `f0`: Содержит вещественные значения в диапазоне от -1.4086 до 2.3623. Среднее значение: 0.5004, стандартное отклонение: 0.8718
# - `f1`: Содержит вещественные значения в диапазоне от -0.8482 до 1.3438. Среднее значение: 0.2501, стандартное отклонение: 0.5044.
# - `f2`: Содержит вещественные значения в диапазоне от -12.0883 до 16.0038. Среднее значение: 2.5026, стандартное отклонение: 3.2482.
# - `product`: Содержит целевую переменную (объем запасов нефти в скважине), представленную вещественными значениями в диапазоне от 0.0000 до 185.3643. Среднее значение: 92.5000, стандартное отклонение: 44.2887.
# - Полные дубликаты и пропуски отсутствуют

# %%
# Посмотрим общую информацию о датафрейме
df_info(geo_data_1)
# Out:
# 1. Первые 5 строк датасета:
#       id         f0         f1        f2     product
# 0  kBEdx -15.001348  -8.276000 -0.005876    3.179103
# 1  62mP7  14.272088  -3.475083  0.999183   26.953261
# 2  vyE1P   6.263187  -5.948386  5.001160  134.766305
# 3  KcrkZ -13.081196 -11.506057  4.999415  137.945408
# 4  AHL4O  12.702195  -8.147433  5.004363  134.766305
# 2. Общая информация о датасете:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 5 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   id       100000 non-null  object
#  1   f0       100000 non-null  float64
#  2   f1       100000 non-null  float64
#  3   f2       100000 non-null  float64
#  4   product  100000 non-null  float64
# dtypes: float64(4), object(1)
# memory usage: 3.8+ MB
# None
#
# 3. Статистика по колонкам:
#             id             f0             f1             f2        product
# ...

# %% [markdown]
# Данные в датафрейме представляют собой набор из 100,000 записей, содержащих 5 колонок:
#
# - `id`: Содержит 99,996 уникальных значений типа строка (object). Наиболее распространённый идентификатор встречается 2 раза. Вероятно, есть записи с дублирующимися `id`.
# - `f0`: Содержит вещественные значения в диапазоне от -31.6096 до 29.4218. Среднее значение: 1.1413, стандартное отклонение: 8.9659.
# - `f1`: Содержит вещественные значения в диапазоне от -26.3586 до 18.7341. Среднее значение: -4.7966, стандартное отклонение: 5.1199.
# - `f2`: Содержит вещественные значения в диапазоне от -0.0181 до 5.0197. Среднее значение: 2.4945, стандартное отклонение: 1.7036.
# - `product`: Содержит вещественные значения в диапазоне от 0.0000 до 137.9454. Среднее значение: 68.8250, стандартное отклонение: 45.9444.
# - Статистика входящих признаков f0, f1, f2 сильно отличаются от первого датасета. Возможно за ними стоят разные реальные характеристики.
# - Полные дубликаты и пропуски отсутствуют.

# %%
# Посмотрим общую информацию о датафрейме
df_info(geo_data_2)
# Out:
# 1. Первые 5 строк датасета:
#       id        f0        f1        f2     product
# 0  fwXo0 -1.146987  0.963328 -0.828965   27.758673
# 1  WJtFt  0.262778  0.269839 -2.530187   56.069697
# 2  ovLUW  0.194587  0.289035 -5.586433   62.871910
# 3  q6cA6  2.236060 -0.553760  0.930038  114.572842
# 4  WPMUX -0.515993  1.716266  5.899011  149.600746
# 2. Общая информация о датасете:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 5 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   id       100000 non-null  object
#  1   f0       100000 non-null  float64
#  2   f1       100000 non-null  float64
#  3   f2       100000 non-null  float64
#  4   product  100000 non-null  float64
# dtypes: float64(4), object(1)
# memory usage: 3.8+ MB
# None
#
# 3. Статистика по колонкам:
#             id             f0             f1             f2        product
# ...

# %% [markdown]
# Данные в датафрейме представляют собой набор из 100,000 записей, содержащих 5 колонок:
#
# - `id`: Содержит 99,996 уникальных значений типа строка (object). Наиболее распространённый идентификатор встречается 2 раза. Вероятно, есть записи с дублирующимися id.
# - `f0`: Содержит вещественные значения в диапазоне от -8.7600 до 7.2383. Среднее значение: 0.0020, стандартное отклонение: 1.7320.
# - `f1`: Содержит вещественные значения в диапазоне от -7.0840 до 7.8448. Среднее значение: -0.0021, стандартное отклонение: 1.7304.
# - `f2`: Содержит вещественные значения в диапазоне от -11.9703 до 16.7394. Среднее значение: 2.4951, стандартное отклонение: 3.4734.
# - `product`: Содержит вещественные значения в диапазоне от 0.0000 до 190.0298. Среднее значение: 95.0000, стандартное отклонение: 44.7499.
# - Статистика входящих параметров снова сильно отличаются от первых двух датасетов.
# - В датасете отсутствуют пропуски и дубликаты.

# %% [markdown]
# ### Предобработка данных

# %%
# посмотрим на скважины с одинаковыми id
print(geo_data_0['id'].duplicated().sum())
print(geo_data_1['id'].duplicated().sum())
print(geo_data_2['id'].duplicated().sum())
# Out:
# 10
# 4
# 4

# %%
# Посмотрим пример таких скважин
geo_data_0[geo_data_0.duplicated('id', keep=False)].sort_values('id')
# Out:
#           id        f0        f1         f2     product
# 66136  74z30  1.084962 -0.312358   6.990771  127.643327
# 64022  74z30  0.741456  0.459229   5.153109  140.771492
# 51970  A5aEY -0.180335  0.935548  -2.094773   33.020205
# 3389   A5aEY -0.039949  0.156872   0.209861   89.249364
# 69163  AGS9W -0.933795  0.116194  -3.655896   19.230453
# 42529  AGS9W  1.454747 -0.479651   0.683380  126.370504
# 931    HZww2  0.755284  0.368511   1.863211   30.681774
# 7530   HZww2  1.061194 -0.373969  10.430210  158.828695
# 63593  QcMuo  0.635635 -0.473422   0.862670   64.578675
# 1949   QcMuo  0.506563 -0.323775  -2.215583   75.496502
# 75715  Tdehs  0.112079  0.430296   3.218993   60.964018
# 21426  Tdehs  0.829407  0.298807  -0.049563   96.035308
# 92341  TtcGQ  0.110711  1.022689   0.911381  101.318008
# 60140  TtcGQ  0.569276 -0.104876   6.440215   85.350186
# 89582  bsk9y  0.398908 -0.400253  10.122376  163.433078
# 97785  bsk9y  0.378429  0.005837   0.160827  160.637302
# ...

# %%
# Посмотрим пример таких скважин
geo_data_1[geo_data_1.duplicated('id', keep=False)].sort_values('id')
# Out:
#           id         f0         f1        f2     product
# 5849   5ltQ6  -3.435401 -12.296043  1.999796   57.085625
# 84461  5ltQ6  18.213839   2.191999  3.993869  107.813044
# 1305   LHZR0  11.170835  -1.945066  3.002872   80.859783
# 41906  LHZR0  -8.989672  -4.286607  2.009139   57.085625
# 2721   bfPNe  -9.494442  -5.463692  4.006042  110.992147
# 82178  bfPNe  -6.202799  -4.820045  2.995107   84.038886
# 47591  wt4Uk  -9.091098  -8.109279 -0.002314    3.179103
# 82873  wt4Uk  10.259972  -9.376355  4.994297  134.766305

# %%
# Посмотрим пример таких скважин
geo_data_2[geo_data_2.duplicated('id', keep=False)].sort_values('id')
# Out:
#           id        f0        f1        f2     product
# 45404  KUPhW  0.231846 -1.698941  4.990775   11.716299
# 55967  KUPhW  1.211150  3.176408  5.543540  132.831802
# 11449  VF7Jo  2.122656 -0.858275  5.746001  181.716817
# 49564  VF7Jo -0.883115  0.560537  0.723601  136.233420
# 44378  Vcm5J -1.229484 -2.439204  1.222909  137.968290
# 95090  Vcm5J  2.587702  1.986875  2.482245   92.327572
# 28039  xCHr8  1.633027  0.368135 -2.378367    6.120525
# 43233  xCHr8 -0.847066  2.101796  5.597130  184.388641

# %%
# посмотрим есть ли дубликаты с повторами во всех других колонках, кроме id
print(geo_data_0.drop('id', axis=1).duplicated().sum())
print(geo_data_1.drop('id', axis=1).duplicated().sum())
print(geo_data_2.drop('id', axis=1).duplicated().sum())
# Out:
# 0
# 0
# 0

# %% [markdown]
# В датасетах есть скважины с одинаковыми id, однако параметры таких скважин отличаются. Возможные причины таких дублирующихся записей:
# - Пробы или оценка некоторых скважин могла производиться несколько раз.
# - Возможна техническая или человеческая ошибка при записи, кодировании данных в колонке `id`.
#
# Фактически колонка с `id` не будет далее использоваться для построения модели машинного обучения, поэтому наличие в ней дубликатов не должно влиять на анализ. Данных дублирующихся записей представляют собой реальные данные о реальных скважинах, поэтому оставим такие данные как есть.

# %% [markdown]
# ### Исследовательский анализ

# %%
plot_box_hist_chart(geo_data_0)

# %% [markdown]
# - **`f0`**: Признак f0 имеет широкий диапазон значений от -1.5 до 2.5, с отсутствием выбросов. Распределение значений f0 имеет четыре пика, что указывает на мультимодальное распределение. Пики значений сосредоточены вокруг целых чисел: -1, 0, 1, 2.
# - **`f1`**: Значения f1 варьируются от -0.5 до 1.5, также без выбросов. Распределение f1 похоже на f0, с тремя пиками и более выраженными значениями в центре, что также указывает на наличие модальности.
# - **`f1`**: Признак f2 показывает широкий диапазон значений от -10 до 15, с наличием выбросов. Распределение f2 близко к нормальному, с одним пиком в центре. Однако присутствие выбросов может искажать представление.
# - **`product`**: Значения product варьируются от 0 до 175, также без значительных выбросов. Распределение имеет множество пиков, что указывает на сложную структуру. Данные как будто формируют несколько групп (кластеров) вокруг определенных значений с одинаковым шагом. Возможно такое распределение данных в целевом признаке связано с особенностями методики прогноза запасов в скважинах (например, это может быть таблица дискретных значений объемов в зависимости от входящих параметров, к которым применяются определенные корректировки). При другом масштабе и сглаживании пиков распределение признака выглядело бы близко к нормальному.

# %%
plot_box_hist_chart(geo_data_1)

# %% [markdown]
# - `f0`: Значения f0 имеют широкий диапазон от -30 до 30 с наличием небольших выбросов. Распределение f0 имеет два выраженных пика, что указывает на бимодальность. Значения сосредоточены в диапазоне от -30 до 30, с наиболее частыми значениями ближе к нулю.
# - `f1`: Значения f1 варьируются от -10 до 20, также с наличием выбросов. Распределение f1 близко к нормальному. Основная масса значений сосредоточена вокруг -5.
# - `f2`: Значения f2 колеблются от 0 до 5, без значительных выбросов. Распределение f2 похоже на равномерное распределение дискретного признака. Возможно это какая-то разбивка скважин на классы.
# - `product`:  Значения product варьируются от 0 до 120, без заметных выбросов. Распределение product также имеет много пиков, что может свидетельствовать о категориальной природе данных. Гистограмма показывает, что значения концентрируются в определенных диапазонах.

# %%
# посмотрим, если ли связь между объемом запасов и признаком f2. 
# для этого округлим данные в f2 до целых и посмотрим статистику по ним
geo_data_1_test = geo_data_1.copy()
geo_data_1_test['f2'] = geo_data_1_test['f2'].round()

# %%
geo_data_1_test.groupby('f2')['product'].agg(['min', 'max', 'mean'])
# Out:
#              min         max        mean
# f2
# -0.0    0.000000    3.179103    1.599335
#  1.0   26.953261   30.132364   28.527461
#  2.0   53.906522   57.085625   55.488343
#  3.0   80.859783   84.038886   82.459868
#  4.0  107.813044  110.992147  109.412419
#  5.0  134.766305  137.945408  136.349032

# %%
geo_data_1_test['f2'].value_counts(normalize=True)
# Out:
#  2.0    0.16862
#  1.0    0.16774
#  3.0    0.16751
# -0.0    0.16572
#  5.0    0.16537
#  4.0    0.16504
# Name: f2, dtype: float64

# %% [markdown]
# Данные выглядят очень подозрительно. Мало того, что параметр f2 четко делит выборку на классы по уровню добычи, так еще выборка содержит скважины каждого уровня в примерно одинаковом количестве.
#
# По условию задачи данные синтетические. Вероятно такая странность связана именно с механизмом генерации данных в этом датасете.
#
# На реальных данных можно было бы сделать вывод о том, что с высокой вероятностью во входящих данных может быть утечка информации о целевом признаке (например, класс скважины был присвоен уже после прогноза запасов). В таком случае для построения модели этот входящий параметр следовало бы исключить.
#
# Если f2 действительно не содержит информации о целевом признаке и был создан независимо, его можно оставить. В противном случае, если есть подозрения на утечку, лучше удалить этот признак из модели.

# %%
plot_box_hist_chart(geo_data_2)

# %% [markdown]
# - Признаки `f0`, `f1`, `f2` распределены нормально. Имеются небольшие выбросы на хвостах распределения.
# - `product`: Значения product варьируются от 0 до 175, без значительных выбросов. Распределение product похоже на распределение в предыдущих таблицах.

# %% [markdown]
# ### Корреляционный анализ

# %%
interval_columns = ['f0', 'f1', 'f2', 'product']

# %%
def plot_heatmap(data, ax, title):
    sns.heatmap(data
                .phik_matrix(interval_cols=interval_columns),
                annot=True,
                annot_kws={"size": 24},  # Увеличенный размер шрифта для аннотаций
                cmap='Greens',
                ax=ax,
                cbar_kws={"format": "%.2f"})
    ax.set_title(title, fontsize=32)  # Увеличенный размер заголовка
    ax.set_xlabel("Показатели", fontsize=24)  # Увеличенный размер шрифта для меток осей
    ax.set_ylabel("Показатели", fontsize=24)
    ax.set_xticklabels(ax.get_xticklabels(), fontsize=24)  # Увеличиваем размер шрифта для меток столбцов
    ax.set_yticklabels(ax.get_yticklabels(), fontsize=24)  # Увеличиваем размер шрифта для меток строк

# Задайте размер фигуры
fig, axes = plt.subplots(1, 3, figsize=(30, 10))

# Построение графиков
plot_heatmap(geo_data_0.drop('id', axis=1), axes[0], "Корреляционная матрица geo_data_0")
plot_heatmap(geo_data_1.drop('id', axis=1), axes[1], "Корреляционная матрица geo_data_1")
plot_heatmap(geo_data_2.drop('id', axis=1), axes[2], "Корреляционная матрица geo_data_2")

# Показать графики
plt.tight_layout()
plt.show()

# %% [markdown]
# **Кореляция целевой переменной**
# - Корреляции целевой переменной и входящих признаков в geo_data_0 и geo_data_2 похожи. В обоих таблицах больше всего коррелирует с уровнем добычи признак f2.
# - Корреляция входящих признаков в geo_data_1 отличается. Признак f2 очень сильно коррелирует с целевой переменной. Как предполагали ранее, вероятно это какой-то класс скважины по размеру запасов. Есть вероятность, что этот входящий признак формировался уже после получения прогноза запасов нефти, однако без описания самих признаков сложно сказать достоверно.
# **Мультиколлинеарность**
# - в первой таблице признаки f0 и f1 имеют достаточно сильную взаимосвязь (коэф. корреляции 0.76) и чуть меньше их связь во второй таблице (0.2). Однако эта связь недостаточно сильная, чтобы утверждать о наличии мультиколлинеарности признаков.
# - Во всех таблицах f3 вообще не коррелирует с другими входящими признаками (только с целевой), а в последнем регионе взаимосвязь входящих признаков отсутствует полностью.

# %% [markdown]
# ### Выводы

# %% [markdown]
# - Получены данные хорошего качества (дубликаты и пропуски отсутствуют).
# - Во всех трех таблицах входящие признаки f0, f1, f2 имеют разное распределение и их статистики совершенно не похожи друг на друга. Вероятно, это совершенно разные показатели, и для каждого региона лучше обучать и строить отдельную модель.
# - В таблице geo_data_2 признак f2 сильно коррелирует с целевой переменной (коэф. корреляции 0.98). Кроме того, значения признака больше похожи на категориальный параметр, чем на непрерывный количественный. Есть основания полагать, что этот признак приводит к утечке целевой переменной и был определен на основе уже существующего прогноза (например, это может быть класс скважины на основе запасов). Учитывая что реальное название характеристики f2 нам не известно, то мы не можем однозначно это утверждать. Если данный признак формировался независимо от целевой переменной, то его лучше оставить при обучении модели, иначе лучше убрать. Далее при построении модели попробуем оценить оба варианта.

# %% [markdown]
# ## Обучение и проверка модели

# %% [markdown]
# ### Подготовка данных

# %%
# Сделаем колонку id индексом во всех датафреймах
geo_data_0 = geo_data_0.set_index('id')
geo_data_1 = geo_data_1.set_index('id')
geo_data_2 = geo_data_2.set_index('id')

# %%
# Функция для разбивки данных на test, valid
def split_on_train_and_valid(data, target_column, valid_ratio):
    X = data.drop(target_column, axis=1).copy()
    y = data[target_column].copy()
    
    # Теперь разделим набор на валидационный и тестовый
    X_train, X_valid, y_train, y_valid = train_test_split(
        X,
        y,
        test_size=valid_ratio,
        random_state=RANDOM_STATE
    )
    
    return X_train, X_valid, y_train, y_valid

# %%
# Разобьем данные на тренировочные и валидационные выборки в пропорции 75:25
X_train_0, X_valid_0, y_train_0, y_valid_0 = split_on_train_and_valid(geo_data_0, 'product', valid_ratio=0.25)
X_train_1, X_valid_1, y_train_1, y_valid_1 = split_on_train_and_valid(geo_data_1, 'product', valid_ratio=0.25)
X_train_2, X_valid_2, y_train_2, y_valid_2 = split_on_train_and_valid(geo_data_2, 'product', valid_ratio=0.25)

# %%
# Удалим признак f2 из X_train_1, X_valid_1 для устранения потенциальной утечки целевого признака
# Запишем новый обучающий сет в отдельную переменную для тестирования
X_train_1_nof2 = X_train_1.drop('f2', axis=1)
X_valid_1_nof2 = X_valid_1.drop('f2', axis=1)

# %% [markdown]
# ### Создание пайплайна

# %%
# Создадим списки с названиями признаков
target =['product']

num_columns = [
    'f0',
    'f1',
    'f2'
]
# список для geo_data_1 без f2
num_columns_1 = [
    'f0',
    'f1'
]

# %%
# Пайплайн предобработки
data_preprocessor = ColumnTransformer(
    [
        ('num', StandardScaler(), num_columns)
    ], 
    remainder='passthrough'
)

# Пайплайн предобработки для geo_data_1
data_preprocessor_1 = ColumnTransformer(
    [
        ('num', StandardScaler(), num_columns_1)
    ], 
    remainder='passthrough'
)

# %%
# создадим итоговый пайплайн
pipe_final = ImbPipeline([
    ('preprocessor', data_preprocessor),
    ('poly', 'passthrough'), 
    ('models', LinearRegression())
])

# %% [markdown]
# ### Обучение и выбор лучшей модели

# %% [markdown]
# #### Выбор метрики

# %% [markdown]
# Для поиска лучшей модели линейной регрессии с помощью GridSearchCV будем использовать метрику RMSE (среднеквадратичная ошибка) по следующим причинам:
#
# - **Интерпретируемость:** RMSE измеряет среднее отклонение предсказанных значений от реальных, что позволяет легко интерпретировать результаты в контексте задач, связанных с объемами запасов.
# - **Чувствительность к выбросам:** RMSE более чувствителен к крупным ошибкам, что важно в задачах, где большие ошибки могут привести к значительным финансовым потерям, как в текущем проекте.
# - **Совпадение с целями бизнеса:** Так как проект связан с оценкой запасов и прибыли, минимизация RMSE поможет лучше предсказывать объемы запасов, что в свою очередь повлияет на финансовые результаты. Кроме того, далее данная метрика также упоминается в задании.

# %% [markdown]
# #### Модель для geo_data_0

# %%
param_grid = [
    # Линейная регрессия без полиномизации признаков
    {
        'preprocessor' : [data_preprocessor],
        'models': [LinearRegression()],
        'models__fit_intercept' : [True, False],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), RobustScaler(), 'passthrough']
    }
]

# %%
# %%time

grid_search_0, results_0 = find_best_model_grid(
    pipe_final,
    param_grid,
    X_train_0,
    y_train_0,
    scoring='neg_root_mean_squared_error'
)
print()
# Out:
# Лучшая модель и её параметры
# Лучшая метрика на кросс-валидации для лучшей модели: 37.67200536313506
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num', StandardScaler(),
#                                                   ['f0', 'f1', 'f2'])])),
#                 ('poly', 'passthrough'), ('models', LinearRegression())])
# CPU times: total: 2.66 s
# Wall time: 3.1 s

# %% [markdown]
# Попробуем использовать полиномизацию признаков (2-3й степени), чтобы улучшить качество модели.

# %%
# Линейная регрессия с полиномизацией признаков 2й и 3й степени
param_grid_poly = [
    {
        'preprocessor' : [data_preprocessor],
        'models': [LinearRegression()],
        'models__fit_intercept' : [True, False],
        'poly': [PolynomialFeatures()],
        'poly__degree': range(2, 4),
        'poly__interaction_only': [True, False],
        'poly__include_bias': [True, False],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), RobustScaler(), 'passthrough']
    }
]

# %%
# %%time

# Попробуем полиномизацию признаков
grid_search_poly_0, results_poly_0 = find_best_model_grid(
    pipe_final,
    param_grid_poly,
    X_train_0,
    y_train_0,
    scoring='neg_root_mean_squared_error'
)
print()
# Out:
# Лучшая модель и её параметры
# Лучшая метрика на кросс-валидации для лучшей модели: 37.26377349598139
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num', 'passthrough',
#                                                   ['f0', 'f1', 'f2'])])),
#                 ('poly', PolynomialFeatures(degree=3)),
#                 ('models', LinearRegression())])
# CPU times: total: 23.5 s
# Wall time: 24.9 s

# %% [markdown]
# С полиномизацией признаков метрика RMSE стала немного лучше (меньше), но из-за полиномизации интерпретируемость модели снижается. Поэтому выберем исходную модель в качестве лучшей и запишем ее в отдельную переменную.

# %%
best_model_0 = grid_search_0

# %% [markdown]
# #### Модель для geo_data_1

# %% [markdown]
# Для начала попробуем обучить модель на полных данных.

# %%
# %%time

grid_search_1, results_1 = find_best_model_grid(
    pipe_final,
    param_grid,
    X_train_1,
    y_train_1,
    scoring='neg_root_mean_squared_error'
)
print()
# Out:
# Лучшая модель и её параметры
# Лучшая метрика на кросс-валидации для лучшей модели: 0.890455962928567
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num', MinMaxScaler(),
#                                                   ['f0', 'f1', 'f2'])])),
#                 ('poly', 'passthrough'), ('models', LinearRegression())])
# CPU times: total: 1.59 s
# Wall time: 1.85 s

# %%
# %%time

# Попробуем полиномизацию признаков
grid_search_poly_1, results_poly_1 = find_best_model_grid(
    pipe_final,
    param_grid_poly,
    X_train_1,
    y_train_1,
    scoring='neg_root_mean_squared_error'
)
print()
# Out:
# Лучшая модель и её параметры
# Лучшая метрика на кросс-валидации для лучшей модели: 0.7822586517348953
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num', 'passthrough',
#                                                   ['f0', 'f1', 'f2'])])),
#                 ('poly', PolynomialFeatures(degree=3)),
#                 ('models', LinearRegression())])
# CPU times: total: 13.4 s
# Wall time: 15.6 s

# %% [markdown]
# С полиномизацией качество улучшилось незначительно, запишем исходную модель как лучшую.

# %%
best_model_1 = grid_search_1

# %% [markdown]
# Модель показывает очень высокое качество, если обучать ее на полных данных. Посмотрим, как изменится качество модели, есль убрать признак f2, который, предположительно, приводит к утечке данных.

# %%
param_grid_1_nof2 = [
    {
        'preprocessor' : [data_preprocessor_1], # изменим дата процессор, чтобы использовать правильные названия колонок
        'models': [LinearRegression()],
        'models__fit_intercept' : [True, False],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), RobustScaler(), 'passthrough']
    }
]

# %%
# %%time

grid_search_1_nof2, results_1_nof2 = find_best_model_grid(
    pipe_final,
    param_grid_1_nof2,
    X_train_1_nof2,
    y_train_1,
    scoring='neg_root_mean_squared_error'
)
print()
# Out:
# Лучшая модель и её параметры
# Лучшая метрика на кросс-валидации для лучшей модели: 45.92441272373849
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num', StandardScaler(),
#                                                   ['f0', 'f1'])])),
#                 ('poly', 'passthrough'), ('models', LinearRegression())])
# CPU times: total: 1.67 s
# Wall time: 1.96 s

# %%
param_grid_poly_1_nof2 = [
    {
        'preprocessor' : [data_preprocessor_1],
        'models': [LinearRegression()],
        'models__fit_intercept' : [True, False],
        'poly': [PolynomialFeatures()],
        'poly__degree': range(2, 4),
        'poly__interaction_only': [True, False],
        'poly__include_bias': [True, False],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), RobustScaler(), 'passthrough']
    }
]

# %%
# %%time

# Попробуем полиномизацию признаков
grid_search_poly_1_nof2, results_poly_1_nof2 = find_best_model_grid(
    pipe_final,
    param_grid_poly_1_nof2,
    X_train_1_nof2,
    y_train_1,
    scoring='neg_root_mean_squared_error'
)
print()
# Out:
# Лучшая модель и её параметры
# Лучшая метрика на кросс-валидации для лучшей модели: 45.92393052726493
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num', MinMaxScaler(),
#                                                   ['f0', 'f1'])])),
#                 ('poly', PolynomialFeatures(degree=3)),
#                 ('models', LinearRegression())])
# CPU times: total: 12.1 s
# Wall time: 13.3 s

# %% [markdown]
# Качество очень сильно ухудшилось, но стало намного больше похоже на предсказания модели по первому региону. Запишем эту модель в отдельную переменную

# %%
# запишем модель без полиномизации в отдельную переменную
best_model_1_nof2 = grid_search_1_nof2

# %% [markdown]
# #### Модель для geo_base_2

# %%
# %%time

grid_search_2, results_2 = find_best_model_grid(
    pipe_final,
    param_grid,
    X_train_2,
    y_train_2,
    scoring='neg_root_mean_squared_error'
)
print()
# Out:
# Лучшая модель и её параметры
# Лучшая метрика на кросс-валидации для лучшей модели: 40.02698159997838
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num', StandardScaler(),
#                                                   ['f0', 'f1', 'f2'])])),
#                 ('poly', 'passthrough'), ('models', LinearRegression())])
# CPU times: total: 1.48 s
# Wall time: 1.77 s

# %%
# %%time

# Попробуем полиномизацию признаков
grid_search_poly_2, results_poly_2 = find_best_model_grid(
    pipe_final,
    param_grid_poly,
    X_train_2,
    y_train_2,
    scoring='neg_root_mean_squared_error'
)
print()
# Out:
# Лучшая модель и её параметры
# Лучшая метрика на кросс-валидации для лучшей модели: 38.69481901844058
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num', StandardScaler(),
#                                                   ['f0', 'f1', 'f2'])])),
#                 ('poly', PolynomialFeatures(degree=3)),
#                 ('models', LinearRegression())])
# CPU times: total: 13.7 s
# Wall time: 15.8 s

# %% [markdown]
# Полиномизация не сильно помогла, используем исходную модель в качестве лучшей.

# %%
best_model_2 = grid_search_2

# %% [markdown]
# #### Dummy-модели

# %%
param_grid_dummy = [
    {
        'preprocessor' : [data_preprocessor],
        'models': [DummyRegressor()],
        'models__strategy': ['mean', 'median'],
    },
    {
        'preprocessor' : [data_preprocessor],
        'models': [DummyRegressor()],
        'models__strategy': ['quantile'],
        'models__quantile': [0.1, 0.25, 0.5, 0.75, 0.9],
    }
]

# %%
# %%time

# для geo_base_0
grid_search_dummy_0, results_base_dummy_0 = find_best_model_grid(
    pipe_final,
    param_grid_dummy,
    X_train_0,
    y_train_0,
    cv=None,
    scoring='neg_root_mean_squared_error'
)
print()
# Out:
# Лучшая модель и её параметры
# Лучшая метрика для лучшей модели: 44.29194255545384
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num', StandardScaler(),
#                                                   ['f0', 'f1', 'f2'])])),
#                 ('poly', 'passthrough'), ('models', DummyRegressor())])
# CPU times: total: 1.58 s
# Wall time: 1.8 s

# %%
# %%time

# для geo_base_1
grid_search_dummy_1, results_base_dummy_1 = find_best_model_grid(
    pipe_final,
    param_grid_dummy,
    X_train_1,
    y_train_1,
    cv=None,
    scoring='neg_root_mean_squared_error'
)
print()
# Out:
# Лучшая модель и её параметры
# Лучшая метрика для лучшей модели: 45.94499182119555
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num', StandardScaler(),
#                                                   ['f0', 'f1', 'f2'])])),
#                 ('poly', 'passthrough'), ('models', DummyRegressor())])
# CPU times: total: 1.47 s
# Wall time: 1.66 s

# %%
# %%time

# для geo_base_2
grid_search_dummy_2, results_base_dummy_2 = find_best_model_grid(
    pipe_final,
    param_grid_dummy,
    X_train_2,
    y_train_2,
    cv=None,
    scoring='neg_root_mean_squared_error'
)
print()
# Out:
# Лучшая модель и её параметры
# Лучшая метрика для лучшей модели: 44.7389090185046
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num', StandardScaler(),
#                                                   ['f0', 'f1', 'f2'])])),
#                 ('poly', 'passthrough'),
#                 ('models', DummyRegressor(strategy='median'))])
# CPU times: total: 1.62 s
# Wall time: 1.93 s

# %% [markdown]
# **geo_base_0:**
# - Метрика лучшей модели линейной регрессии: 37.6720
# - Метрика Dummy-модели: 44.2919
#
# **geo_base_1:**
# - Метрика лучшей модели линейной регрессии (полная): 0.8905
# - Метрика лучшей модели линейной регрессии (без f2): 45.9244
# - Метрика Dummy-модели: 45.9450
#
# **geo_base_2:**
# - Метрика лучшей модели линейной регрессии: 40.0269
# - Метрика Dummy-модели: 44.7389
#
# Модели линейной регрессии (кроме geo_base_1 с полными данными) справились ненамного лучше, чем примитивные модели, предсказывающие среднее значение или медиану.
#
# Метрика второй модели (без параметра f2) вообще практически не отличается от метрики примитивной модели. Скорей всего качество получившейся модели в данном случае ужасное и она не подходит для предсказаний.

# %% [markdown]
# ### Предсказания на валидационной выборке

# %% [markdown]
# Получим предсказания для каждого региона.

# %% [markdown]
# #### Модель geo_base_0

# %%
# Предсказания для региона geo_data_0
y_valid_pred_0 = analyze_model_predictions(best_model_0, X_train_0, X_valid_0, y_valid_0)
# Out:
# Первые 5 строк тренировочного датасета (после обработки):
#     num__f0   num__f1   num__f2
# 0  1.274786 -0.799739 -0.396677
# 1 -1.600689  0.234678 -2.169283
# 2 -0.323791  1.436297  1.495425
# 3  0.439038  0.830679  0.185881
# 4 -1.652805  0.761012  0.111734
# R2 LinearRegression = 0.2728
# MSE = 1425.5609
# RMSE = 37.7566
# MAE = 31.0477
#
# Среднее предсказанное значение = 92.3988

# %%
plot_residuals(y_valid_0, y_valid_pred_0)

# %% [markdown]
# **Качество модели**
# - **R² (Коэффициент детерминации):** Значение 0.2728 указывает на то, что модель объясняет лишь 27.28% вариации зависимой переменной. Это достаточно низкий показатель, что говорит о том, что модель не способна хорошо предсказывать целевую переменную.
# - **MSE (Среднеквадратичная ошибка):** Значение 1425.5609 указывает на то, насколько предсказания модели отклоняются от фактических значений в среднем. Чем меньше это значение, тем лучше, однако в данном случае оно довольно высокое.
# - **RMSE (Корень из среднеквадратичной ошибки):** Значение 37.7566 показывает среднее расстояние между предсказанными и фактическими значениями. Это значение также достаточно высокое, что говорит о слабой точности модели.
# - **MAE (Средняя абсолютная ошибка):** Значение 31.0477 показывает среднее абсолютное отклонение предсказаний от фактических значений. Это значение также указывает на значительные ошибки в предсказаниях.
# - **Среднее предсказанное значение:** Значение 92.3988 дает представление о том, что модель в среднем предсказывает значения около 92.4. Это может быть полезно для понимания общего уровня предсказаний, но без высокой точности это значение имеет ограниченное значение.
#
# **Анализ остатков**
# - **Центрирование остатков:** Остатки (разница между наблюдаемыми и предсказанными значениями) расположены вокруг нуля, что является хорошим знаком. Это говорит о том, что модель в целом не имеет систематической ошибки.
# - **Гетероскедастичность остатков:** Распределение остатков не является постоянным и изменяется в зависимости от предсказанных значений. На графике остатки формируют фигуру похожую на развернутый прямоугольник. При этом с ростом предсказанных значений, модель все чаще может завышать значение добычи. Гетероскедастичность может указывать на то, что модель не учитывает все важные переменные или взаимодействия.
# - **Линии среднего и медианного остатков:** Средняя и медианная линии близки к нулю, что подтверждает отсутствие смещения в модели.
# - **Форма распределения:** Гистограмма остатков показывает форму, приближенную к нормальному распределению, что является хорошим признаком для линейной регрессии.
# - **Среднее и медиана:** Среднее и медиана остатков также близки друг к другу и к нулю, что подтверждает отсутствие смещения.
#
#
# В общем, модель получилось достаточно низкого качества. Вероятно, входящих признаков слишком мало для адекватного обучения модели. Для улучшения его качества, рекомендуется произвести сбор дополнительных характеристик скажин, позволяющих предсказать объяем запасов нефти.

# %% [markdown]
# #### Модель geo_base_1

# %%
# Предсказания для региона geo_data_1
y_valid_pred_1 = analyze_model_predictions(best_model_1, X_train_1, X_valid_1, y_valid_1)
# Out:
# Первые 5 строк тренировочного датасета (после обработки):
#     num__f0   num__f1   num__f2
# 0  0.670245  0.507669  0.400505
# 1  0.777410  0.656945  0.993959
# 2  0.491791  0.602175  0.599759
# 3  0.720045  0.460593  0.400872
# 4  0.436742  0.425384  0.202391
# R2 LinearRegression = 0.9996
# MSE = 0.7926
# RMSE = 0.8903
# MAE = 0.7170
#
# Среднее предсказанное значение = 68.7129

# %%
plot_residuals(y_valid_1, y_valid_pred_1)

# %% [markdown]
# **Качество модели**
# - **R² (Коэффициент детерминации):** Значение коэффициента (0.9996) близко к 1, что говорит о том, что модель объясняет 99.96% вариации зависимой переменной. Это очень высокий показатель, указывающий на отличную адаптацию модели к данным.
# - **MSE (Среднеквадратичная ошибка):** Низкое значение MSE (0.7926) указывает на то, что предсказания модели близки к фактическим значениям. В данном случае значение 0.7926 говорит о хорошем качестве модели.
# - **RMSE (Корень из среднеквадратичной ошибки):** Это значение тоже низкое (0.8903), что говорит о том, что ошибки предсказаний незначительны. В данном случае ошибка предсказания составляет примерно 0.89 тыс. баррелей.
# - **MAE (Средняя абсолютная ошибка):** Значение 0.7170 также говорит о том, что предсказания модели достаточно точны и в среднем отличаются от фактических значений на 0.717.
# - **Среднее предсказанное значение:** Среднее значение запасов в этом регионе (68.7129) ниже чем в первом.
#
# **Анализ остатков**
#
# - **Структура остатков:** Остатки имеют выраженный "столбчатый" вид, что указывает на наличие систематической ошибки. Видно, что остатки колеблются в узком диапазоне, а их распределение имеет вид, похожий на "параллелепипед". Это может означать, что модель не совсем адекватно описывает данные и ей не хватает признаков для описания модели.
# - **Гетероскедастичность**: Остатки кажутся равномерно распределенными, но наличие "параллельных" слоев может указывать на гетероскедастичность, где разброс остатков варьируется в зависимости от предсказанных значений.
# - **Линии среднего и медианного остатков:** Среднее и медиана остатков близки к нулю, что говорит о том, что в целом модель не имеет смещения. Однако наличие выраженной структуры может указывать на то, что модель не учитывает все важные факторы.
# - **Форма распределения:** Гистограмма остатков имеет приближенную нормальную форму, что является положительным признаком.
# - **Симметричность:** Среднее и медиана остатков расположены близко друг к другу, что подтверждает отсутствие смещения.
#
#
# Модель линейной регрессии демонстрирует отличные результаты, с высокой объясняющей способностью и низкими значениями ошибок. Это указывает на то, что модель хорошо справляется с предсказаниями на данном наборе данных. ПРи этом визуальные признаки на графиках остатков указывают на то, что модель может не совсем адекватно описывать данные. Это может быть связано с пропущенными переменными или нелинейными зависимостями в данных.
#
# Кроме того, ранее мы предпоожили что параметр `f2` может приводить к утечке данных. Возможно именно поэтому модель показала такое отличное качество.

# %% [markdown]
# Посмотрим на предсказания модели, обученной без учета признака f2.

# %%
# Предсказания для региона geo_data_1_nof2
y_valid_pred_1_nof2 = analyze_model_predictions(best_model_1_nof2, X_train_1_nof2, X_valid_1_nof2, y_valid_1)
# Out:
# Первые 5 строк тренировочного датасета (после обработки):
#     num__f0   num__f1
# 0  0.911229  0.063780
# 1  1.640885  1.320793
# 2 -0.303818  0.859595
# 3  1.250304 -0.332629
# 4 -0.678630 -0.629111
# R2 LinearRegression = 0.0009
# MSE = 2109.0138
# RMSE = 45.9240
# MAE = 40.2992
#
# Среднее предсказанное значение = 68.8489

# %%
plot_residuals(y_valid_1, y_valid_pred_1_nof2)

# %% [markdown]
# **Качество модели**
# - **R² (Коэффициент детерминации):** Значение 0.0009 говорит о том, что модель практически не объясняет вариацию зависимой переменной. Это крайне низкий показатель, указывающий на то, что модель не имеет предсказательной способности. Ранее мы видели, что модель справляется с предсказание примерно также как и примитивный алгоритм всегда предсказывающий среднее или медиану. Использовать ее для предсказаний не рекомендуется.
# - **MSE (Среднеквадратичная ошибка):** Значение 2109.0138 означает, что в среднем предсказания модели сильно отклоняются от фактических значений. Это также указывает на плохую точность модели.
# - **RMSE (Корень из среднеквадратичной ошибки):** Значение 45.9240 показывает, что среднее расстояние между предсказанными и фактическими значениями довольно велико. Это также свидетельствует о низком качестве предсказаний.
# - **MAE (Средняя абсолютная ошибка):** Значение 40.2992 указывает на среднее абсолютное отклонение предсказаний от истинных значений. Это значение высокое и подтверждает слабую точность модели.
# - **Среднее предсказанное значение:** Значение 68.8489 показывает, что модель в среднем предсказывает значения около 68.8. Однако, учитывая крайне низкие показатели качества, это значение может быть неинформативным.
#
# **Анализ остатков**
# - **Структура остатков:** Остатки имеют выраженный полосатый вид, что указывает на наличие систематической ошибки. Наблюдается явная структура, где остатки группируются в определенные диапазоны. Кроме того, эти линии уьывают с ростом предсказаний модели. Это может означать, что модель не учитывает важные факторы.
# - **Гетероскедастичность:** Распределение остатков указывает на гетероскедастичность, так как разброс остатков варьируется в зависимости от предсказанных значений. Это может свидетельствовать о том, что разброс ошибок увеличивается с увеличением значений предсказаний.
# - **Линии среднего и медианного остатков:** Среднее и медиана остатков расположены близко к нулю, что указывает на отсутствие смещения в модели. Тем не менее, наличие структурных особенностей может говорить о недостатках в модели.
# - **Форма распределения:** Гистограмма демонстрирует четкую периодическую структуру с несколькими пиками, что говорит о наличии систематической ошибки. Это может означать, что модель не учитывает какие-то эффекты в данных.
# - **Симметричность:** Среднее и медиана остатков расположены вблизи друг друга, но наличие нескольких пиков может указывать на многомодальное распределение, что говорит о вероятном наличии различных подгрупп данных, которые модель не смогла учесть.
#
#
# В целом, модель имеет ужасное качество и требует значительной доработки. Необходимо исследовать данные, возможно, добавить новые признаки или попробовать другие алгоритмы, чтобы повысить предсказательную способность. Предсказательная сила это модели сравнима с заполнением прогнозных значений медианой или средним значением по выборке.

# %% [markdown]
# #### Модель geo_base_2

# %%
# Предсказания для региона geo_data_2
y_valid_pred_2 = analyze_model_predictions(best_model_2, X_train_2, X_valid_2, y_valid_2)
# Out:
# Первые 5 строк тренировочного датасета (после обработки):
#     num__f0   num__f1   num__f2
# 0 -0.343864 -1.338311  0.817572
# 1 -0.400431  0.993613 -1.102974
# 2  1.004849 -0.923485 -0.576264
# 3 -0.784031  0.571573  0.914886
# 4  0.619771  0.681588 -0.429467
# R2 LinearRegression = 0.1963
# MSE = 1611.6911
# RMSE = 40.1459
# MAE = 32.8970
#
# Среднее предсказанное значение = 94.771

# %%
plot_residuals(y_valid_2, y_valid_pred_2)

# %% [markdown]
# Метрики модели и распределение остатков очень близко к самому первому региону.
#
# Качество модели получилось лучше чем для geo_data_1, но немного хуже чем geo_data_0. В целом, модель достаточно низкого качества. Вероятно, входящих признаков слишком мало для адекватного обучения модели. Для улучшения его качества, рекомендуется произвести сбор дополнительных характеристик скажин, позволяющих предсказать объем запасов нефти.

# %% [markdown]
# ### Выводы

# %% [markdown]
# В данном разделе было проделан следующий анализ:
#
# **1. Подготовка данных**
# - Все датафреймы были подготовлены путем установки колонки id в качестве индекса.
# - Данные были разделены на тренировочные и валидационные выборки в пропорции 75:25.
#
# **2. Обучение моделей**
# - Для каждой из моделей (geo_base_0, geo_base_1, geo_base_2) проводился поиск лучших гиперпараметров с использованием модели линейной регрессии. Поиск лучшей модели производился с учетом метрики RMSE.
# - Для сравнения были также протестированы метрики примитивных моделей DummyRegressor.
# - В случае geo_base_1 была проведена дополнительная проверка модели без признака f2, который мог вызывать утечку целевого признака.
#
# **3. Результаты моделей**
# - geo_base_0
#  - R²: 0.2728 (низкая объясняющая способность)
#  - MSE: 1425.5609 (высокое значение, указывает на плохую точность)
#  - RMSE: 37.7566
#  - MAE: 31.0477
#  - Модель показывает низкое качество, вероятно, из-за недостатка признаков.
# - geo_base_1
#  - С полным набором данных:
#      - R²: 0.9996 (очень высокая объясняющая способность)
#      - MSE: 0.7926
#      - RMSE: 0.8903
#      - MAE: 0.7170
#  - Без признака f2:
#      - R²: 0.0009 (практически не объясняет вариацию)
#      - MSE: 2109.0138 (очень высокое)
#      - RMSE = 45.9240
#      - MAE = 40.2992
# - geo_base_2
#  - R²: 0.1963 (низкая объясняющая способность)
#  - MSE: 1611.6911
#  - RMSE: 40.1459
#  - MAE: 32.8970
#  - Модель показывает качество, близкое к geo_base_0, но хуже, чем у geo_base_1.
#
# **Общие выводы**
# - Модели линейной регрессии показали низкое качество, за исключением geo_base_1 с полным набором данных.
# - Высокие метрики для geo_base_1 могут быть следствием утечки данных через признак f2.
# - Рекомендуется произвести сбор дополнительных признаков для улучшения качества моделей или рассмотреть возможность испоьзования других алгоритмов машинного обучения для повышения предсказательной способности моделей.

# %% [markdown]
# ## Подготовка к расчёту прибыли

# %%
BUDGET = 1*10**10
RESEARCH_POINTS = 500
BEST_POINTS = 200
PRICE = 450*1000
LOSS_THRESHOLD = 0.025

# %%
# бюджет на разработку 1 скважины
BUDGET / BEST_POINTS
# Out:
# 50000000.0

# %%
# достаточный объём сырья для безубыточной разработки одной новой скважины (тыс. баррелей)
BUDGET / BEST_POINTS / PRICE
# Out:
# 111.11111111111111

# %%
print(f'Средний запас нефти одной скважины в регионе 0: {geo_data_0["product"].mean()}')
print(f'Средний запас нефти одной скважины  в регионе 1: {geo_data_1["product"].mean()}')
print(f'Средний запас нефти одной скважины  в регионе 2: {geo_data_2["product"].mean()}')
# Out:
# Средний запас нефти одной скважины в регионе 0: 92.50000000000001
# Средний запас нефти одной скважины  в регионе 1: 68.82500000000002
# Средний запас нефти одной скважины  в регионе 2: 95.00000000000004

# %% [markdown]
# Во всех трех регионах средний запас нефти в скважинах немного ниже, чем точка безубыточности для текущей бизнес-модели.
#
# Это означает, что объем нефти, который можно добыть из одной скважины, в среднем недостаточен для покрытия всех затрат на ее разработку и эксплуатацию. Кроме того, очевидно, что разрабатывать все (или выбранные случайным образом) скважины в любом регионе, скорей всего, будет не выгодно. Поэтому необходимо выбрать скважины (200 шт) таким образом, чтобы средний запас нефти в них в среднем превышал 111 тыс. баррелей для того, чтобы проект окупился.
#
# Больше всего средний размер запасов находится в регионе 2, меньше всего в регионе 1.

# %%
# Напишем функцию для подсчета прибыли
def profit(target, target_pred, count):
    """
    Вычисляет прибыль на основе предсказанных значений и целевых значений.

    Параметры:
    - target (pd.Series): Целевые значения.
    - target_pred (pd.Series или array): Предсказанные значения, которые используются для выбора лучших целевых значений.
    - count (int): Количество целевых значений, которые нужно выбрать для расчета прибыли.

    Возвращает:
    - float: Расчетная прибыль, полученная от выбранных целевых значений.
    """
    
    # Проверяем, является ли target_pred объектом pd.Series
    # Если нет, преобразуем его в pd.Series с тем же индексом, что и у target
    if not isinstance(target_pred, pd.Series):
        target_pred = pd.Series(target_pred, index=target.index)

    # Сортируем предсказанные значения в порядке убывания
    target_pred_sorted = target_pred.sort_values(ascending=False)

    # Выбираем целевые значения на основе индекса отсортированных предсказаний
    # Берем первые 'count' целевых значений
    selected = target[target_pred_sorted.index][:count]

    # Рассчитываем и возвращаем прибыль
    # Прибыль = (Сумма выбранных целевых значений * Цена) - Бюджет
    return selected.sum() * PRICE - BUDGET

# %% [markdown]
# ## Расчёт прибыли и рисков

# %%
def calculate_bootstrap(target, target_pred):
    """
    Выполняет бутстрэп-анализ для оценки прибыли и рисков.

    Параметры:
    target (pd.Series): Фактические значения целевой переменной.
    target_pred (array-like): Массив предсказанных значений целевой переменной.

    Вывод:
    Выводит среднюю прибыль, доверительный интервал и риск убытка.
    """
    # Преобразуем предсказанные значения в Series с теми же индексами, что и у целевых значений
    predictions = pd.Series(target_pred, index=target.index)
    
    values = []  # Список для хранения результатов прибыли
    loss_count = 0  # Счетчик убытков

    # Выполняем 1000 итераций бутстрэп-анализ
    for i in range(1000):
        # Получаем бутстрэп-выборку предсказаний с возвращением
        predictions_subsample = predictions.sample(RESEARCH_POINTS, replace=True, random_state=STATE)
        target_subsample = target[predictions_subsample.index]  # Соответствующие целевые значения
        result = profit(target_subsample, predictions_subsample, BEST_POINTS)  # Вычисляем прибыль
        values.append(result)  # Сохраняем результат
        
        # Увеличиваем счетчик убытков, если результат отрицательный
        if result < 0:
            loss_count += 1

    # Рассчитываем и выводим среднюю прибыль в миллионах рублей
    mean_profit = sum(values) / len(values)
    print(f'Средняя прибыль: {mean_profit / 1_000_000:.2f} млн. рублей')

    # Рассчитываем 95%-ый доверительный интервал прибыли
    lower_bound = np.percentile(values, 2.5)
    upper_bound = np.percentile(values, 97.5)
    print(f'95%-ый доверительный интервал прибыли: {lower_bound / 1_000_000:.2f} - {upper_bound / 1_000_000:.2f} млн. рублей')
    
    # Рассчитываем и выводим риск убытка в процентах
    loss_risk = loss_count / len(values)
    print(f'Риск убытка: {loss_risk * 100:.2f}%')
    
    # Оцениваем, подходит ли регион для разработки на основе риска убытка
    if loss_risk < LOSS_THRESHOLD:
        print('Регион подходит для разработки')
    else:
        print("Риски слишком велики!")

# %%
def calculate_bootstrap(target, target_pred):
    """
    Выполняет бутстрэп-анализ для оценки прибыли и рисков.

    Параметры:
    target (pd.Series): Фактические значения целевой переменной.
    target_pred (array-like): Массив предсказанных значений целевой переменной.

    Вывод:
    Выводит среднюю прибыль, доверительный интервал и риск убытка.
    """
    # Преобразуем предсказанные значения в Series с теми же индексами, что и у целевых значений
    predictions = pd.Series(target_pred, index=target.index)
    
    values = []  # Список для хранения результатов прибыли
    loss_count = 0  # Счетчик убытков

    # Выполняем 1000 итераций бутстрэп-анализ
    for i in range(1000):
        # Получаем бутстрэп-выборку предсказаний с возвращением
        predictions_subsample = predictions.sample(RESEARCH_POINTS, replace=True, random_state=STATE)
        target_subsample = target[predictions_subsample.index]  # Соответствующие целевые значения
        result = profit(target_subsample, predictions_subsample, BEST_POINTS)  # Вычисляем прибыль
        values.append(result)  # Сохраняем результат
        
        # Увеличиваем счетчик убытков, если результат отрицательный
        if result < 0:
            loss_count += 1

    # Рассчитываем и выводим среднюю прибыль в миллионах рублей
    mean_profit = sum(values) / len(values)
    print(f'Средняя прибыль: {mean_profit / 1_000_000:.2f} млн. рублей')

    # Рассчитываем 95%-ый доверительный интервал прибыли
    lower_bound = np.percentile(values, 2.5)
    upper_bound = np.percentile(values, 97.5)
    print(f'95%-ый доверительный интервал прибыли: {lower_bound / 1_000_000:.2f} - {upper_bound / 1_000_000:.2f} млн. рублей')
    
    # Рассчитываем и выводим риск убытка в процентах
    loss_risk = loss_count / len(values)
    print(f'Риск убытка: {loss_risk * 100:.2f}%')
    
    # Оцениваем, подходит ли регион для разработки на основе риска убытка
    if loss_risk < LOSS_THRESHOLD:
        print('Регион подходит для разработки')
    else:
        print("Риски слишком велики!")

    # Построение графика распределения значений
    plt.figure(figsize=(10, 6))
    sns.histplot(values, bins=30, kde=True, color='blue')
    plt.title('Распределение прибыли')
    plt.xlabel('Прибыль (руб.)')
    plt.ylabel('Частота')
    plt.axvline(mean_profit, color='red', linestyle='dashed', linewidth=2, label='Средняя прибыль')
    plt.axvline(lower_bound, color='green', linestyle='dashed', linewidth=2, label='Нижний доверительный интервал')
    plt.axvline(upper_bound, color='green', linestyle='dashed', linewidth=2, label='Верхний доверительный интервал')
    plt.legend()
    plt.grid()
    plt.show()

# %%
# Оценим прибыль и риски для региона 0
calculate_bootstrap(y_valid_0, y_valid_pred_0)
# Out:
# Средняя прибыль: 435.93 млн. рублей
# 95%-ый доверительный интервал прибыли: -116.23 - 966.50 млн. рублей
# Риск убытка: 6.10%
# Риски слишком велики!

# %%
# Оценим прибыль и риски для региона 1 (полная модель)
calculate_bootstrap(y_valid_1, y_valid_pred_1)
# Out:
# Средняя прибыль: 498.57 млн. рублей
# 95%-ый доверительный интервал прибыли: 75.32 - 911.50 млн. рублей
# Риск убытка: 1.00%
# Регион подходит для разработки

# %%
# Оценим прибыль и риски для региона 1 (без учета f2)
calculate_bootstrap(y_valid_1, y_valid_pred_1_nof2)
# Out:
# Средняя прибыль: -3701.68 млн. рублей
# 95%-ый доверительный интервал прибыли: -4315.82 - -3091.20 млн. рублей
# Риск убытка: 100.00%
# Риски слишком велики!

# %%
# Оценим прибыль и риски для региона 2
calculate_bootstrap(y_valid_2, y_valid_pred_2)
# Out:
# Средняя прибыль: 403.52 млн. рублей
# 95%-ый доверительный интервал прибыли: -171.95 - 934.56 млн. рублей
# Риск убытка: 8.10%
# Риски слишком велики!

# %% [markdown]
# ### Выводы

# %% [markdown]
# На основе проведенного анализа прибыли и рисков можно сделать следующие выводы:
#
# - Регион 1 (полная модель) является наиболее перспективным для бурения новой скважины, так как он демонстрирует наивысшую среднюю прибыль и минимальный риск убытка.
# - Регионы 0 и 2 также имеют положительные показатели ожидаемой прибыли, но риск убытка в них слишком велик.
# - При этом важно учитывать, что если переменная f2 для Региона 1 не является независимой и приводит к утечке целевого признака, то полученная модель может показывать слишком оптимистичные результаты. Без учета переменной f2 качество модели становится ужасным и она показывает худшие результаты с гарантированными убытками на большую сумму. Следует обязательно учитывать это обстоятельство при принятии окончательного решения об инвестировании в данный регион.
# - Модели для Региона 0 и Региона 2 получились низкого качество. Моделям явно не хватает объяснительных данных для предсказания целевой переменной. По возможности рекомендуется собрать дополнительные данные о характеристиках скважин и особенностях регионов, влияющих на нефтедобычу. Улучшение качества моделей может помочь с большей уверенностью выбрать прибыльные скважины и регион разработки, увеличить ожидаемую прибыль и снизить возможные риски для инвестиций. Добавление новых параметров может оказать существенное влияние на результаты проведенного анализа и выбор лучшего региона.
